# %%
from pythonpic.classes import Grid, Species, Simulation
# %matplotlib inline
from pythonpic.visualization.static_plots import electrostatic_energy_time_plots
from pythonpic.configs.run_coldplasma import cold_plasma_oscillations
import matplotlib.pyplot as plt

# %%
for frequency in [1, 2, 5]:
    filename = f"docs_run_energy_drift_{frequency}"
    run = cold_plasma_oscillations(filename, frequency, T=50).lazy_run()
    run.grid.postprocess_fourier()
    fig, ax = plt.subplots()
    electrostatic_energy_time_plots(run, ax)
# Out:
# Path is data_analysis/coldplasma/docs_run_energy_drift_1/docs_run_energy_drift_1.hdf5
# Running simulation
# Saved file to data_analysis/coldplasma/docs_run_energy_drift_1/docs_run_energy_drift_1.hdf5
# Postprocessing grid.
# Postprocessing electrons.
# Postprocessing simulation.
# Path is data_analysis/coldplasma/docs_run_energy_drift_2/docs_run_energy_drift_2.hdf5
# Running simulation
# Saved file to data_analysis/coldplasma/docs_run_energy_drift_2/docs_run_energy_drift_2.hdf5
# Postprocessing grid.
# Postprocessing electrons.
# Postprocessing simulation.
# Path is data_analysis/coldplasma/docs_run_energy_drift_5/docs_run_energy_drift_5.hdf5
# Running simulation
# Saved file to data_analysis/coldplasma/docs_run_energy_drift_5/docs_run_energy_drift_5.hdf5
# Postprocessing grid.
# Postprocessing electrons.
# Postprocessing simulation.
